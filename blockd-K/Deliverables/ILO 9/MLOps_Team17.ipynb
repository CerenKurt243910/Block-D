# %% [markdown]
# ### Template for evidencing MLOps & Deployment

# %% [markdown]
# #### Section 1: Setting up environment

# %%
##### For all members in the team, provide screenshots of setting up poetry 
##### for your group project with the same structure. 
#### This should include installation of poetry with the same folder name.

# %% [markdown]
# ### Zofia Pilitowska
#
# ![Screenshot showing the setup of poetry](Poetry_setup_Zofia_Pilitowska_240272.png "Poetry setup")

# %% [markdown]
# Ceren Kurt
#
# ![Screenshot showing the setup of poetry](Poetry_setup_Ceren_Kurt_243910.png "Poetry setup")

# %% [markdown]
# ### Filip Šarík
#
# ![Screenshot showing the setup of poetry](Poetry_setup_Filip_Sarik_243537.png "Poetry setup")

# %% [markdown]
# Maks Burchard
#
# ![Screenshot showing the setup of poetry](Poetry_setup_Maks_Burchard_240894.png "Poetry setup")

# %%
##### Similarly, provide the screenshot of the contents of pyproject.toml file

# %% [markdown]
# ![Screenshot showing the contents of the pyproject.toml file](Pyproject-TOML.png "Contents of pyproject.toml")

# %% [markdown]
# #### Section 2: Collaborative Work

# %%
##### Provide evidence that each member of the group committed and pushed to the group repository at least once
##### Format is provided below for evidencing.

# %% [markdown]
# #### StudentID 1- Zofia Pilitowska

# %%
### Git commit and push evidence - Paste the GitHub links for respective student

### https://github.com/BredaUniversityADSAI/2024-25-y1d-teamwork-group-17/commit/982d4966dc064b07ee18ffc45f3657948ece6b26 
### https://github.com/BredaUniversityADSAI/2024-25-y1d-teamwork-group-17/commit/5498e67a49399b6fb6db0ebccd2d696f74ac6ccb 
### https://github.com/BredaUniversityADSAI/2024-25-y1d-teamwork-group-17/commit/a737009e474e3b55517ba059982a3bf77aae3e94

# %% [markdown]
# #### StudentID 2- Ceren Kurt

# %%
### Git commit and push evidence - Paste the GitHub links for respective student

### https://github.com/BredaUniversityADSAI/2024-25-y1d-teamwork-group-17/commit/5dd38721cd9a786742325e49bbd692f43735d99c
### https://github.com/BredaUniversityADSAI/2024-25-y1d-teamwork-group-17/commit/721e531b4ea2b33b4d4c7cab949ef87583767a86
### https://github.com/BredaUniversityADSAI/2024-25-y1d-teamwork-group-17/commit/d271f61acb1d60aa595abd4d8deb5c1aaa94efcc

# %% [markdown]
# #### StudentID 3- Filip Šarík

# %%
### Git commit and push evidence - Paste the GitHub links for respective student

### https://github.com/BredaUniversityADSAI/2024-25-y1d-teamwork-group-17/commit/4c85fc014dd622b3305bd5bfab227ffd46264b09
### https://github.com/BredaUniversityADSAI/2024-25-y1d-teamwork-group-17/commit/228edf6378dcc606e0ea80ec3cb4ffbc85b95f8d
### https://github.com/BredaUniversityADSAI/2024-25-y1d-teamwork-group-17/commit/186712ccb9e2f84a12e8fdd34505348b793c24f9

# %% [markdown]
# #### StudentID 4- Maks Burchard

# %%
### Git commit and push evidence - Paste the GitHub links for respective student

### https://github.com/BredaUniversityADSAI/2024-25-y1d-teamwork-group-17/commit/8fa7fd797a020003a0f99074b2f8af9f4a74e4a1
### https://github.com/BredaUniversityADSAI/2024-25-y1d-teamwork-group-17/commit/71960f973eec63e572f2975f7b742039f46547d5
### https://github.com/BredaUniversityADSAI/2024-25-y1d-teamwork-group-17/commit/35e622038d215bf35bdc0aa34b8f3be5f1529f41

# %% [markdown]
# #### Section 3: Modularizing code

# %%
### Provide directory structure of the project in modularized format
### Example structure is provided below
### Evidence should be in the form of screenshots
### Navigate to your poetry parent directory, and run the command - tree
### Running the command will provide a screenshot like below 
### Upload the screenshot to github repo and link the screenshot here

### https://github.com/BredaUniversityADSAI/2024-25-y1d-teamwork-group-17/blob/5452e79b586d623a7d6974127be85fb28f7b756b/Deliverables/ILO%209/structure_full.png

# %% [markdown]
# ```
# iris_predictor/
# ├── src/
# │   └── iris_predictor/
# │       ├── __init__.py
# │       ├── data_loader.py       # loads and splits iris data
# │       ├── model.py             # model training and prediction
# │       ├── metrics.py           # evaluation metrics
# │       └── config.py            # configurable settings
# ├── tests/
# │   ├── __init__.py
# │   └── test_model.py
# ├── pyproject.toml
# ├── README.md
# └── .gitignore
# ```

# %%
#### data_loader.py
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

def load_data(test_size=0.2, random_state=42):
    iris = load_iris()
    X_train, X_test, y_train, y_test = train_test_split(
        iris.data, iris.target, test_size=test_size, random_state=random_state
    )
    return X_train, X_test, y_train, y_test

# %%
##### model.py
from sklearn.ensemble import RandomForestClassifier
from iris_predictor.data_loader import load_data

def train_model():
    X_train, X_test, y_train, y_test = load_data()
    model = RandomForestClassifier()
    model.fit(X_train, y_train)
    return model, X_test, y_test

def predict(model, X):
    return model.predict(X)

# %%
#### metrics.py
from sklearn.metrics import accuracy_score, classification_report

def evaluate(y_true, y_pred):
    return {
        "accuracy": accuracy_score(y_true, y_pred),
        "report": classification_report(y_true, y_pred, output_dict=True)
    }

# %%
#### __init__.py
from .model import train_model, predict
from .metrics import evaluate

# %%
#### config.py
# You can extend this file to control hyperparameters or paths
CONFIG = {
    "test_size": 0.2,
    "random_state": 42
}

# %% [markdown]
# #### Section 4: Code Formatting

# %%
#### 1. Provide evidence for the usage of logging (Screenshot)
#### 2. Provide evidence for using flake8 and black that resolves linting issues (Screenshot)
#### 3. Provide evidence for refactoring your code  (Screenshot)

# %% [markdown]
# Before logging:
#
# ![Screenshot showing how the code was before logging](logging_data_preprocessing_before.png "Logging not being used")
#
# After logging:
#
# ![Screenshot showing usage of logging](logging_data_preprocessing.png "Logging being used")

# %% [markdown]
# Flake8:
#
# ![Screenshot showing usage of flake8](flake8_everything.png "Flake8 being used")
#
# Black:
#
# ![Screenshot showing usage of black](black.png "Black being used")

# %% [markdown]
# Refactoring:
#
# Before:
#
# ![Screenshot showing how it was before refactoring](refactoring_false.png "Before refracturing")
#
# After:
#
# ![Screenshot showing refactoring](refactoring_true.png "Refracturing")

# %% [markdown]
# #### Section 5: Unit Test Coverage

# %%
### Provide evidence that at least 3 of your modules are tested and 80% of the test cases are covered. (Screenshot)

# %% [markdown]
# ![Screenshot showing 80% of test and 80% coverage](Poetry_coverage.png "80%")

# %% [markdown]
# #### Section 6: Documentation

# %%
### Attach PDF version of the generated document from pdocs or sphinx

# %% [markdown]
# [Link to PDF file](https://github.com/BredaUniversityADSAI/2024-25-y1d-teamwork-group-17/blob/e0d0e3ccd195b12c256e5b9d89ed81bf7ba25f7c/stocks_predictor/docs/build/latex/stocks_predictor.pdf)

# %% [markdown]
# #### Section 7: Final Application Demo

# %%
#### Link to the Final Application Demo or at least 3 screenshots of the application running locally

# %% [markdown]
# [Link to Demo Video in GitHub](https://github.com/BredaUniversityADSAI/2024-25-y1d-teamwork-group-17/blob/e0d0e3ccd195b12c256e5b9d89ed81bf7ba25f7c/Deliverables/ILO%204/SmartPredict_Demo.mp4)
